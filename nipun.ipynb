# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Running cells with 'Python 3.9.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
qualifying_df = pd.read_csv('./data/qualifying.csv')
races_df = pd.read_csv('./data/races.csv')
results_df = pd.read_csv('./data/results.csv')
seasons_df = pd.read_csv('./data/seasons.csv')

# %% [markdown]
# #### Qualifying dataset

# %%
qualifying_df.shape
# Out:
# (9395, 9)

# %%
qualifying_df.head()
# Out:
#    qualifyId  raceId  driverId  constructorId  number  position        q1  \
# 0          1      18         1              1      22         1  1:26.572
# 1          2      18         9              2       4         2  1:26.103
# 2          3      18         5              1      23         3  1:25.664
# 3          4      18        13              6       2         4  1:25.994
# 4          5      18         2              2       3         5  1:25.960
#
#          q2        q3
# 0  1:25.187  1:26.714
# 1  1:25.315  1:26.869
# 2  1:25.452  1:27.079
# 3  1:25.691  1:27.178
# 4  1:25.518  1:27.236

# %%
qualifying_df.describe()
# Out:
#          qualifyId       raceId     driverId  constructorId       number  \
# count  9395.000000  9395.000000  9395.000000    9395.000000  9395.000000
# mean   4708.067802   567.057477   295.588292      42.516338    17.727515
# std    2724.048557   416.228721   374.391151      69.108188    17.522644
# min       1.000000     1.000000     1.000000       1.000000     0.000000
# 25%    2350.500000   114.000000    15.000000       4.000000     7.000000
# 50%    4700.000000   847.000000    45.000000       9.000000    14.000000
# 75%    7068.500000   965.000000   817.000000      25.000000    21.000000
# max    9452.000000  1086.000000   855.000000     214.000000    99.000000
#
#           position
# count  9395.000000
# mean     11.278233
# std       6.310997
# min       1.000000
# 25%       6.000000
# 50%      11.000000
# 75%      17.000000
# max      28.000000

# %%
qualifying_df.isnull().sum()
# Out:
# qualifyId          0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# position           0
# q1                 8
# q2               151
# q3               294
# dtype: int64

# %% [markdown]
# #### Races dataset

# %%
races_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 races_df.shape
#
# NameError: name 'races_df' is not defined

# %%
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# ...

# %%
races_df_mod = races_df.drop(['url', 'fp1_date', 'fp1_time', 'fp2_date', 'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time', 'sprint_date', 'sprint_time'], axis = 1)

# %%
races_df_mod.drop(['date'], axis = 1, inplace = True)

# %%
races_df_mod
# Out:
#       raceId  year  round  circuitId                      name      time
# 0          1  2009      1          1     Australian Grand Prix  06:00:00
# 1          2  2009      2          2      Malaysian Grand Prix  09:00:00
# 2          3  2009      3         17        Chinese Grand Prix  07:00:00
# 3          4  2009      4          3        Bahrain Grand Prix  12:00:00
# 4          5  2009      5          4        Spanish Grand Prix  12:00:00
# ...      ...   ...    ...        ...                       ...       ...
# 1074    1092  2022     18         22       Japanese Grand Prix  05:00:00
# 1075    1093  2022     19         69  United States Grand Prix  19:00:00
# 1076    1094  2022     20         32    Mexico City Grand Prix  20:00:00
# 1077    1095  2022     21         18      Brazilian Grand Prix  18:00:00
# 1078    1096  2022     22         24      Abu Dhabi Grand Prix  13:00:00
#
# [1079 rows x 6 columns]

# %% [markdown]
# #### Results dataset

# %%
results_df.shape
# Out:
# (25660, 18)

# %%
results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
results_df.describe()
# Out:
#            resultId        raceId      driverId  constructorId          grid  \
# count  25660.000000  25660.000000  25660.000000   25660.000000  25660.000000
# mean   12831.305105    527.495830    258.558496      48.299532     11.187256
# std     7408.686039    296.776908    265.708300      59.354624      7.251983
# min        1.000000      1.000000      1.000000       1.000000      0.000000
# 25%     6415.750000    291.000000     56.000000       6.000000      5.000000
# 50%    12830.500000    511.000000    160.000000      25.000000     11.000000
# 75%    19245.250000    777.000000    358.000000      58.000000     17.000000
# max    25665.000000   1086.000000    855.000000     214.000000     34.000000
#
#        positionOrder        points          laps      statusId
# count   25660.000000  25660.000000  25660.000000  25660.000000
# mean       12.892673      1.854523     45.936204     17.634528
# std         7.721729      4.131527     29.867844     26.161012
# ...

# %%
results_df.isnull().sum()
# Out:
# resultId           0
# raceId             0
# driverId           0
# constructorId      0
# number             0
# grid               0
# position           0
# positionText       0
# positionOrder      0
# points             0
# laps               0
# time               0
# milliseconds       0
# fastestLap         0
# rank               0
# fastestLapTime     0
# fastestLapSpeed    0
# statusId           0
# dtype: int64

# %%
results_df['fastestLapTime'].value_counts()
# Out:
# \N          18454
# 1:18.262        4
# 1:17.495        4
# 1:43.026        4
# 1:38.702        3
#             ...
# 1:50.375        1
# 1:52.601        1
# 1:58.313        1
# 1:59.290        1
# 1:24.002        1
# Name: fastestLapTime, Length: 6627, dtype: int64

# %%
results_df['positionText'].value_counts()
# Out:
# R     8781
# F     1368
# 3     1080
# 4     1080
# 2     1078
# 5     1076
# 1     1073
# 6     1068
# 7     1049
# 8     1021
# 9      983
# 10     923
# 11     847
# 12     745
# 13     658
# 14     551
# 15     475
# 16     385
# W      330
# 17     291
# 18     191
# N      190
# D      147
# 19     123
# 20      65
# 21      34
# 22      19
# E        9
# 23       8
# 24       3
# 29       1
# 32       1
# 31       1
# 30       1
# 25       1
# 28       1
# 27       1
# 26       1
# 33       1
# Name: positionText, dtype: int64

# %%
results_df.drop(['time', 'milliseconds'], axis = 1, inplace = True)

# %% [markdown]
# #### Seasons dataset

# %%
seasons_df.shape
# Out:
# (73, 2)

# %%
seasons_df.head()
# Out:
#    year                                                url
# 0  2009  http://en.wikipedia.org/wiki/2009_Formula_One_...
# 1  2008  http://en.wikipedia.org/wiki/2008_Formula_One_...
# 2  2007  http://en.wikipedia.org/wiki/2007_Formula_One_...
# 3  2006  http://en.wikipedia.org/wiki/2006_Formula_One_...
# 4  2005  http://en.wikipedia.org/wiki/2005_Formula_One_...

# %%
seasons_df.describe()
# Out:
#               year
# count    73.000000
# mean   1986.000000
# std      21.217131
# min    1950.000000
# 25%    1968.000000
# 50%    1986.000000
# 75%    2004.000000
# max    2022.000000

# %%
seasons_df.isnull().sum()
# Out:
# year    0
# url     0
# dtype: int64

# %%
races_df.loc[races_df['raceId'] == 1061]
# Out:
#       raceId  year  round  circuitId                name        date  \
# 1046    1061  2021     10          9  British Grand Prix  2021-07-18
#
#           time                                                url    fp1_date  \
# 1046  14:00:00  http://en.wikipedia.org/wiki/2021_British_Gran...  2021-07-16
#
#      fp1_time    fp2_date fp2_time fp3_date fp3_time  quali_date quali_time  \
# 1046       \N  2021-07-17       \N       \N       \N  2021-07-16         \N
#
#      sprint_date sprint_time
# 1046  2021-07-17          \N

# %%
races_df['posionOrder'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nipun\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\nipun\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\nipun\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'posionOrder'
#
# ...
