# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./data/train.csv')

# %%
a = data['year'].unique()
np.random.shuffle(a)
val_years = a[:6]

len(data[data['year'].isin(val_years)].index)
# Out:
# 2409

# %%
data
# Out:
#        raceId  year  circuitId  weather_warm  weather_cold  weather_dry  \
# 0           1  2009  -1.399483           1.0           0.0          0.0
# 1          90  2004  -1.399483           0.0           0.0          1.0
# 2         108  2003  -1.399483           1.0           0.0          1.0
# 3         841  2011  -1.399483           0.0           0.0          0.0
# 4         860  2012  -1.399483           0.0           0.0          0.0
# ...       ...   ...        ...           ...           ...          ...
# 23267     815  1953  -2.247691           0.0           0.0          1.0
# 23268     817  1952  -2.247691           1.0           0.0          0.0
# 23269     815  1953  -2.247691           0.0           0.0          1.0
# 23270     832  1951  -1.465374           0.0           0.0          1.0
# 23271     832  1951  -1.465374           0.0           0.0          1.0
#
#        weather_wet  weather_cloudy  driverId  constructorId  ...  \
# ...

# %%
temp = data[data['raceId'] == 1].index

# %%
data['results_positionOrder'][temp]
# Out:
# 0        1
# 271      2
# 578      3
# 815      4
# 891      5
# 1202     6
# 1370     7
# 1406     8
# 1433     9
# 1523    10
# 1702    11
# 1943    20
# 2177    19
# 2278    15
# 2589    16
# 3437    12
# 5315    14
# 5470    13
# 7705    18
# 9143    17
# Name: results_positionOrder, dtype: int64
