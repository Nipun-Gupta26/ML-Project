# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
df_train = pd.read_csv('../../data_new/train_pre.csv').drop_duplicates()
df_test = pd.read_csv('../../data_new/test_pre.csv').drop_duplicates()

# %%
def pooled_var(stds):
    n = 3 # size of each group
    return np.sqrt(sum((n-1)*(stds**2))/ len(stds)*(n-1))

# %%
def plot_cv_results(gs_model, gs_params):
    df = pd.DataFrame(gs_model.cv_results_)
    results = ['mean_test_score',
            'mean_train_score',
            'std_test_score', 
            'std_train_score']


    fig, axes = plt.subplots(1, len(gs_params), 
                            figsize = (5*len(gs_params), 7),
                            sharey='row')
    axes[0].set_ylabel("Score", fontsize=25)
    lw = 2

    for idx, (param_name, param_range) in enumerate(gs_params.items()):
        grouped_df = df.groupby(f'param_{param_name}')[results]\
            .agg({'mean_train_score': 'mean',
                'mean_test_score': 'mean',
                'std_train_score': pooled_var,
                'std_test_score': pooled_var})

        previous_group = df.groupby(f'param_{param_name}')[results]
        axes[idx].set_xlabel(param_name, fontsize=30)
        axes[idx].set_ylim(0.0, 1.1)
        axes[idx].plot(param_range, grouped_df['mean_train_score'], label="Training score",
                    color="darkorange", lw=lw)
        axes[idx].fill_between(param_range, grouped_df['mean_train_score'] - grouped_df['std_train_score'],
                        grouped_df['mean_train_score'] + grouped_df['std_train_score'], alpha=0.2,
                        color="darkorange", lw=lw)
        axes[idx].plot(param_range, grouped_df['mean_test_score'], label="Cross-validation score",
                    color="navy", lw=lw)
        axes[idx].fill_between(param_range, grouped_df['mean_test_score'] - grouped_df['std_test_score'],
                        grouped_df['mean_test_score'] + grouped_df['std_test_score'], alpha=0.2,
                        color="navy", lw=lw)

    handles, labels = axes[0].get_legend_handles_labels()
    fig.suptitle('Validation curves', fontsize=40)
    fig.legend(handles, labels, loc=8, ncol=2, fontsize=20)

    fig.subplots_adjust(bottom=0.25, top=0.85)  
    plt.show()

# %%
def get_score(pred, actual):
    if np.argmin(pred) == np.argmin(actual):
        return 1
    return 0

# %%
def get_metrics(model, x, y):
    precision = 0
    accuracy = 0
    recall = 0
    f1 = 0
    score = 0
    for i in x['raceId'].unique():
        X_test = x[x['raceId'] == i]
        Y_test = y[x[x['raceId'] == i].index]

        predicted_scores = model.predict(X_test.drop(columns = ['results_positionOrder']))
        predicted_podium = np.argsort(predicted_scores)[::-1]
        # print(self.position[x[x['raceId'] == i].index])
        actual_podium = X_test['results_positionOrder'].to_numpy()
        actual_podium = np.argsort(actual_podium)
        # print(predicted_scores)

        predictions = np.zeros(len(Y_test))
        # predictions[predicted_podium] = 1
        actual = np.zeros(len(Y_test))
        # actual[actual_podium] = 1

        for i in range(1):
            predictions[predicted_podium[i]] = 1
            # print(actual_podium)
            actual[actual_podium[i]] = 1

        precision += precision_score(actual, predictions)
        accuracy += accuracy_score(actual, predictions)
        recall += recall_score(actual, predictions)
        f1 += f1_score(actual, predictions) 
        score += get_score(predicted_podium, actual_podium)
    return precision/len(x['raceId'].unique()), accuracy/len(x['raceId'].unique()), recall/len(x['raceId'].unique()), f1/len(x['raceId'].unique()), score/len(x['raceId'].unique())

# %%
class customCrossValidation():

    def split(self, x):
        indices = []
        for i in range(3):
            years = x['year'].unique()
            np.random.shuffle(years)
            val_years = years[:6]
            train_years = years[6:]

            indices.append((x[x['year'].isin(train_years)].index, x[x['year'].isin(val_years)].index))
        return indices

# %% [markdown]
# ##### Ridge Regression

# %%
class RFRegression() :

    def scoring(self, model, x, y):

        precision = 0
        accuracy = 0
        recall = 0
        f1 = 0
        score = 0
        for i in x['raceId'].unique():
            X_test = x[x['raceId'] == i]
            Y_test = y[x[x['raceId'] == i].index]

            predicted_scores = model.predict(X_test)
            predicted_podium = np.argsort(predicted_scores)[::-1]
            # print(self.position[x[x['raceId'] == i].index])
            actual_podium = self.position[x[x['raceId'] == i].index].to_numpy()
            actual_podium = np.argsort(actual_podium)
            # print(predicted_scores)

            predictions = np.zeros(len(Y_test))
            # predictions[predicted_podium] = 1
            actual = np.zeros(len(Y_test))
            # actual[actual_podium] = 1

            for i in range(1):
                predictions[predicted_podium[i]] = 1
                # print(actual_podium)
                actual[actual_podium[i]] = 1

            precision += precision_score(actual, predictions)
            accuracy += accuracy_score(actual, predictions)
            recall += recall_score(actual, predictions)
            f1 += f1_score(actual, predictions) 
            score += get_score(predicted_podium, actual_podium)
        
        # self.ridge_metrics = {'precision': precision/len(x['raceId'].unique()), 'accuracy': accuracy/len(x['raceId'].unique()), 'recall': recall/len(x['raceId'].unique()), 'f1': f1/len(x['raceId'].unique())}
        return precision/len(x['raceId'].unique())

    def find_best_param_rf(self, x, y):

        self.x = x
        self.y = y
        self.position = x['results_positionOrder']

        splitter = customCrossValidation().split(x)
        self.hyper_params = [{'n_estimators': [100, 200, 300], 'max_depth': [5, 10, 15, 20], 'min_samples_split': [2, 5, 10, 15]}]

        model_rf = RandomForestRegressor()
        self.model_cv = GridSearchCV(estimator=model_rf, param_grid=self.hyper_params, scoring=self.scoring, cv = splitter, return_train_score=True, verbose = 3)
        self.model_cv.fit(x.drop(columns = ['results_positionOrder']), y)
        self.rf_params = self.model_cv.best_params_

    def fit_rf(self, x, y):
        model = RandomForestRegressor(**self.rf_params)
        model.fit(x.drop(columns = ['results_positionOrder']), y)
        self.model = model
        return

# %%
rf = RFRegression()

# %%
rf.find_best_param_rf(df_train.drop(columns = ['results_points']), df_train['results_points'])
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV 1/3] END max_depth=5, min_samples_split=2, n_estimators=100;, score=(train=0.554, test=0.595) total time=   3.1s
# [CV 2/3] END max_depth=5, min_samples_split=2, n_estimators=100;, score=(train=0.560, test=0.576) total time=   2.9s
# [CV 3/3] END max_depth=5, min_samples_split=2, n_estimators=100;, score=(train=0.562, test=0.460) total time=   3.3s
# [CV 1/3] END max_depth=5, min_samples_split=2, n_estimators=200;, score=(train=0.553, test=0.560) total time=   5.4s
# [CV 2/3] END max_depth=5, min_samples_split=2, n_estimators=200;, score=(train=0.559, test=0.565) total time=   5.6s
# [CV 3/3] END max_depth=5, min_samples_split=2, n_estimators=200;, score=(train=0.567, test=0.476) total time=   5.4s
# [CV 1/3] END max_depth=5, min_samples_split=2, n_estimators=300;, score=(train=0.550, test=0.583) total time=   8.2s
# [CV 2/3] END max_depth=5, min_samples_split=2, n_estimators=300;, score=(train=0.562, test=0.565) total time=   8.2s
# [CV 3/3] END max_depth=5, min_samples_split=2, n_estimators=300;, score=(train=0.562, test=0.460) total time=   7.8s
# [CV 1/3] END max_depth=5, min_samples_split=5, n_estimators=100;, score=(train=0.553, test=0.548) total time=   2.9s
# [CV 2/3] END max_depth=5, min_samples_split=5, n_estimators=100;, score=(train=0.554, test=0.588) total time=   2.9s
# [CV 3/3] END max_depth=5, min_samples_split=5, n_estimators=100;, score=(train=0.568, test=0.476) total time=   2.8s
# [CV 1/3] END max_depth=5, min_samples_split=5, n_estimators=200;, score=(train=0.555, test=0.571) total time=   5.5s
# [CV 2/3] END max_depth=5, min_samples_split=5, n_estimators=200;, score=(train=0.562, test=0.576) total time=   5.5s
# [CV 3/3] END max_depth=5, min_samples_split=5, n_estimators=200;, score=(train=0.563, test=0.476) total time=   5.3s
# [CV 1/3] END max_depth=5, min_samples_split=5, n_estimators=300;, score=(train=0.556, test=0.560) total time=   8.2s
# [CV 2/3] END max_depth=5, min_samples_split=5, n_estimators=300;, score=(train=0.565, test=0.565) total time=   8.3s
# [CV 3/3] END max_depth=5, min_samples_split=5, n_estimators=300;, score=(train=0.561, test=0.492) total time=   7.9s
# [CV 1/3] END max_depth=5, min_samples_split=10, n_estimators=100;, score=(train=0.556, test=0.595) total time=   2.9s
# [CV 2/3] END max_depth=5, min_samples_split=10, n_estimators=100;, score=(train=0.562, test=0.565) total time=   3.0s
# [CV 3/3] END max_depth=5, min_samples_split=10, n_estimators=100;, score=(train=0.569, test=0.492) total time=   2.8s
# [CV 1/3] END max_depth=5, min_samples_split=10, n_estimators=200;, score=(train=0.550, test=0.595) total time=   5.6s
# [CV 2/3] END max_depth=5, min_samples_split=10, n_estimators=200;, score=(train=0.559, test=0.576) total time=   6.0s
# [CV 3/3] END max_depth=5, min_samples_split=10, n_estimators=200;, score=(train=0.562, test=0.476) total time=   5.5s
# [CV 1/3] END max_depth=5, min_samples_split=10, n_estimators=300;, score=(train=0.555, test=0.595) total time=   8.4s
# [CV 2/3] END max_depth=5, min_samples_split=10, n_estimators=300;, score=(train=0.560, test=0.565) total time=   8.2s
# [CV 3/3] END max_depth=5, min_samples_split=10, n_estimators=300;, score=(train=0.562, test=0.460) total time=   8.0s
# [CV 1/3] END max_depth=5, min_samples_split=15, n_estimators=100;, score=(train=0.551, test=0.583) total time=   3.1s
# [CV 2/3] END max_depth=5, min_samples_split=15, n_estimators=100;, score=(train=0.563, test=0.588) total time=   2.9s
# [CV 3/3] END max_depth=5, min_samples_split=15, n_estimators=100;, score=(train=0.560, test=0.476) total time=   2.8s
# [CV 1/3] END max_depth=5, min_samples_split=15, n_estimators=200;, score=(train=0.550, test=0.571) total time=   5.5s
# [CV 2/3] END max_depth=5, min_samples_split=15, n_estimators=200;, score=(train=0.558, test=0.565) total time=   5.7s
# [CV 3/3] END max_depth=5, min_samples_split=15, n_estimators=200;, score=(train=0.563, test=0.460) total time=   5.3s
# [CV 1/3] END max_depth=5, min_samples_split=15, n_estimators=300;, score=(train=0.551, test=0.595) total time=   8.2s
# [CV 2/3] END max_depth=5, min_samples_split=15, n_estimators=300;, score=(train=0.562, test=0.565) total time=   8.3s
# [CV 3/3] END max_depth=5, min_samples_split=15, n_estimators=300;, score=(train=0.566, test=0.492) total time=   7.8s
# [CV 1/3] END max_depth=10, min_samples_split=2, n_estimators=100;, score=(train=0.798, test=0.583) total time=   4.9s
# [CV 2/3] END max_depth=10, min_samples_split=2, n_estimators=100;, score=(train=0.791, test=0.647) total time=   4.9s
# [CV 3/3] END max_depth=10, min_samples_split=2, n_estimators=100;, score=(train=0.791, test=0.460) total time=   4.8s
# [CV 1/3] END max_depth=10, min_samples_split=2, n_estimators=200;, score=(train=0.798, test=0.595) total time=   9.6s
# [CV 2/3] END max_depth=10, min_samples_split=2, n_estimators=200;, score=(train=0.807, test=0.624) total time=   9.6s
# [CV 3/3] END max_depth=10, min_samples_split=2, n_estimators=200;, score=(train=0.794, test=0.476) total time=   9.3s
# [CV 1/3] END max_depth=10, min_samples_split=2, n_estimators=300;, score=(train=0.801, test=0.560) total time=  14.1s
# [CV 2/3] END max_depth=10, min_samples_split=2, n_estimators=300;, score=(train=0.800, test=0.635) total time=  14.2s
# [CV 3/3] END max_depth=10, min_samples_split=2, n_estimators=300;, score=(train=0.793, test=0.476) total time=  14.0s
# [CV 1/3] END max_depth=10, min_samples_split=5, n_estimators=100;, score=(train=0.782, test=0.571) total time=   4.9s
# [CV 2/3] END max_depth=10, min_samples_split=5, n_estimators=100;, score=(train=0.777, test=0.612) total time=   5.3s
# [CV 3/3] END max_depth=10, min_samples_split=5, n_estimators=100;, score=(train=0.770, test=0.476) total time=   5.2s
# [CV 1/3] END max_depth=10, min_samples_split=5, n_estimators=200;, score=(train=0.789, test=0.583) total time=   9.8s
# [CV 2/3] END max_depth=10, min_samples_split=5, n_estimators=200;, score=(train=0.785, test=0.612) total time=  10.8s
# [CV 3/3] END max_depth=10, min_samples_split=5, n_estimators=200;, score=(train=0.773, test=0.476) total time=  11.1s
# [CV 1/3] END max_depth=10, min_samples_split=5, n_estimators=300;, score=(train=0.786, test=0.583) total time=  16.3s
# [CV 2/3] END max_depth=10, min_samples_split=5, n_estimators=300;, score=(train=0.785, test=0.647) total time=  14.1s
# [CV 3/3] END max_depth=10, min_samples_split=5, n_estimators=300;, score=(train=0.783, test=0.476) total time=  14.0s
# [CV 1/3] END max_depth=10, min_samples_split=10, n_estimators=100;, score=(train=0.752, test=0.619) total time=   4.8s
# [CV 2/3] END max_depth=10, min_samples_split=10, n_estimators=100;, score=(train=0.751, test=0.647) total time=   4.8s
# [CV 3/3] END max_depth=10, min_samples_split=10, n_estimators=100;, score=(train=0.761, test=0.476) total time=   5.0s
# [CV 1/3] END max_depth=10, min_samples_split=10, n_estimators=200;, score=(train=0.760, test=0.583) total time=  10.2s
# [CV 2/3] END max_depth=10, min_samples_split=10, n_estimators=200;, score=(train=0.758, test=0.624) total time=   9.5s
# [CV 3/3] END max_depth=10, min_samples_split=10, n_estimators=200;, score=(train=0.755, test=0.476) total time=   9.2s
# [CV 1/3] END max_depth=10, min_samples_split=10, n_estimators=300;, score=(train=0.751, test=0.583) total time=  13.9s
# [CV 2/3] END max_depth=10, min_samples_split=10, n_estimators=300;, score=(train=0.753, test=0.635) total time=  14.4s
# [CV 3/3] END max_depth=10, min_samples_split=10, n_estimators=300;, score=(train=0.759, test=0.476) total time=  14.0s
# [CV 1/3] END max_depth=10, min_samples_split=15, n_estimators=100;, score=(train=0.734, test=0.571) total time=   4.9s
# [CV 2/3] END max_depth=10, min_samples_split=15, n_estimators=100;, score=(train=0.745, test=0.624) total time=   4.9s
# [CV 3/3] END max_depth=10, min_samples_split=15, n_estimators=100;, score=(train=0.725, test=0.492) total time=   4.8s
# [CV 1/3] END max_depth=10, min_samples_split=15, n_estimators=200;, score=(train=0.744, test=0.571) total time=   9.4s
# [CV 2/3] END max_depth=10, min_samples_split=15, n_estimators=200;, score=(train=0.746, test=0.624) total time=   9.5s
# [CV 3/3] END max_depth=10, min_samples_split=15, n_estimators=200;, score=(train=0.734, test=0.444) total time=   9.3s
# [CV 1/3] END max_depth=10, min_samples_split=15, n_estimators=300;, score=(train=0.739, test=0.583) total time=  14.5s
# [CV 2/3] END max_depth=10, min_samples_split=15, n_estimators=300;, score=(train=0.729, test=0.612) total time=  14.0s
# [CV 3/3] END max_depth=10, min_samples_split=15, n_estimators=300;, score=(train=0.729, test=0.476) total time=  13.9s
# [CV 1/3] END max_depth=15, min_samples_split=2, n_estimators=100;, score=(train=0.960, test=0.548) total time=   6.7s
# [CV 2/3] END max_depth=15, min_samples_split=2, n_estimators=100;, score=(train=0.959, test=0.576) total time=   6.8s
# [CV 3/3] END max_depth=15, min_samples_split=2, n_estimators=100;, score=(train=0.954, test=0.444) total time=   6.7s
# [CV 1/3] END max_depth=15, min_samples_split=2, n_estimators=200;, score=(train=0.959, test=0.548) total time=  13.2s
# [CV 2/3] END max_depth=15, min_samples_split=2, n_estimators=200;, score=(train=0.964, test=0.635) total time=  13.3s
# [CV 3/3] END max_depth=15, min_samples_split=2, n_estimators=200;, score=(train=0.954, test=0.460) total time=  13.4s
# [CV 1/3] END max_depth=15, min_samples_split=2, n_estimators=300;, score=(train=0.956, test=0.536) total time=  21.2s
# [CV 2/3] END max_depth=15, min_samples_split=2, n_estimators=300;, score=(train=0.962, test=0.624) total time=  20.7s
# [CV 3/3] END max_depth=15, min_samples_split=2, n_estimators=300;, score=(train=0.957, test=0.508) total time=  20.9s
# [CV 1/3] END max_depth=15, min_samples_split=5, n_estimators=100;, score=(train=0.928, test=0.595) total time=   7.0s
# [CV 2/3] END max_depth=15, min_samples_split=5, n_estimators=100;, score=(train=0.931, test=0.624) total time=   7.1s
# [CV 3/3] END max_depth=15, min_samples_split=5, n_estimators=100;, score=(train=0.921, test=0.476) total time=   6.9s
# [CV 1/3] END max_depth=15, min_samples_split=5, n_estimators=200;, score=(train=0.932, test=0.583) total time=  13.7s
# [CV 2/3] END max_depth=15, min_samples_split=5, n_estimators=200;, score=(train=0.932, test=0.635) total time=  13.8s
# [CV 3/3] END max_depth=15, min_samples_split=5, n_estimators=200;, score=(train=0.927, test=0.444) total time=  14.1s
# [CV 1/3] END max_depth=15, min_samples_split=5, n_estimators=300;, score=(train=0.940, test=0.595) total time=  20.3s
# [CV 2/3] END max_depth=15, min_samples_split=5, n_estimators=300;, score=(train=0.941, test=0.624) total time=  20.8s
# [CV 3/3] END max_depth=15, min_samples_split=5, n_estimators=300;, score=(train=0.933, test=0.460) total time=  24.9s
# [CV 1/3] END max_depth=15, min_samples_split=10, n_estimators=100;, score=(train=0.878, test=0.595) total time=   6.7s
# [CV 2/3] END max_depth=15, min_samples_split=10, n_estimators=100;, score=(train=0.881, test=0.588) total time=   7.1s
# [CV 3/3] END max_depth=15, min_samples_split=10, n_estimators=100;, score=(train=0.864, test=0.508) total time=   6.5s
# [CV 1/3] END max_depth=15, min_samples_split=10, n_estimators=200;, score=(train=0.878, test=0.583) total time=  13.7s
# [CV 2/3] END max_depth=15, min_samples_split=10, n_estimators=200;, score=(train=0.876, test=0.624) total time=  13.1s
# [CV 3/3] END max_depth=15, min_samples_split=10, n_estimators=200;, score=(train=0.872, test=0.476) total time=  13.0s
# [CV 1/3] END max_depth=15, min_samples_split=10, n_estimators=300;, score=(train=0.884, test=0.595) total time=  20.2s
# [CV 2/3] END max_depth=15, min_samples_split=10, n_estimators=300;, score=(train=0.875, test=0.624) total time=  19.5s
# [CV 3/3] END max_depth=15, min_samples_split=10, n_estimators=300;, score=(train=0.873, test=0.476) total time=  19.3s
# [CV 1/3] END max_depth=15, min_samples_split=15, n_estimators=100;, score=(train=0.831, test=0.560) total time=   6.5s
# [CV 2/3] END max_depth=15, min_samples_split=15, n_estimators=100;, score=(train=0.831, test=0.624) total time=   6.6s
# [CV 3/3] END max_depth=15, min_samples_split=15, n_estimators=100;, score=(train=0.828, test=0.508) total time=   6.4s
# [CV 1/3] END max_depth=15, min_samples_split=15, n_estimators=200;, score=(train=0.832, test=0.560) total time=  12.7s
# [CV 2/3] END max_depth=15, min_samples_split=15, n_estimators=200;, score=(train=0.832, test=0.635) total time=  12.8s
# [CV 3/3] END max_depth=15, min_samples_split=15, n_estimators=200;, score=(train=0.828, test=0.476) total time=  12.8s
# [CV 1/3] END max_depth=15, min_samples_split=15, n_estimators=300;, score=(train=0.830, test=0.571) total time=  19.3s
# [CV 2/3] END max_depth=15, min_samples_split=15, n_estimators=300;, score=(train=0.833, test=0.624) total time=  19.9s
# [CV 3/3] END max_depth=15, min_samples_split=15, n_estimators=300;, score=(train=0.835, test=0.460) total time=  19.8s
# [CV 1/3] END max_depth=20, min_samples_split=2, n_estimators=100;, score=(train=0.986, test=0.512) total time=   8.1s
# [CV 2/3] END max_depth=20, min_samples_split=2, n_estimators=100;, score=(train=0.986, test=0.612) total time=   8.4s
# [CV 3/3] END max_depth=20, min_samples_split=2, n_estimators=100;, score=(train=0.987, test=0.524) total time=   8.3s
# [CV 1/3] END max_depth=20, min_samples_split=2, n_estimators=200;, score=(train=0.985, test=0.548) total time=  16.2s
# [CV 2/3] END max_depth=20, min_samples_split=2, n_estimators=200;, score=(train=0.989, test=0.600) total time=  18.0s
# [CV 3/3] END max_depth=20, min_samples_split=2, n_estimators=200;, score=(train=0.989, test=0.476) total time=  15.3s
# [CV 1/3] END max_depth=20, min_samples_split=2, n_estimators=300;, score=(train=0.989, test=0.571) total time=  22.9s
# [CV 2/3] END max_depth=20, min_samples_split=2, n_estimators=300;, score=(train=0.986, test=0.624) total time=  26.0s
# [CV 3/3] END max_depth=20, min_samples_split=2, n_estimators=300;, score=(train=0.989, test=0.429) total time=  24.0s
# [CV 1/3] END max_depth=20, min_samples_split=5, n_estimators=100;, score=(train=0.954, test=0.583) total time=   8.3s
# [CV 2/3] END max_depth=20, min_samples_split=5, n_estimators=100;, score=(train=0.958, test=0.624) total time=   8.1s
# [CV 3/3] END max_depth=20, min_samples_split=5, n_estimators=100;, score=(train=0.957, test=0.460) total time=   8.6s
# [CV 1/3] END max_depth=20, min_samples_split=5, n_estimators=200;, score=(train=0.955, test=0.560) total time=  16.0s
# [CV 2/3] END max_depth=20, min_samples_split=5, n_estimators=200;, score=(train=0.963, test=0.624) total time=  16.9s
# [CV 3/3] END max_depth=20, min_samples_split=5, n_estimators=200;, score=(train=0.947, test=0.492) total time=  15.5s
# [CV 1/3] END max_depth=20, min_samples_split=5, n_estimators=300;, score=(train=0.956, test=0.548) total time=  24.2s
# [CV 2/3] END max_depth=20, min_samples_split=5, n_estimators=300;, score=(train=0.964, test=0.612) total time=  23.6s
# [CV 3/3] END max_depth=20, min_samples_split=5, n_estimators=300;, score=(train=0.959, test=0.492) total time=  22.4s
# [CV 1/3] END max_depth=20, min_samples_split=10, n_estimators=100;, score=(train=0.900, test=0.595) total time=   7.2s
# [CV 2/3] END max_depth=20, min_samples_split=10, n_estimators=100;, score=(train=0.884, test=0.612) total time=   7.3s
# [CV 3/3] END max_depth=20, min_samples_split=10, n_estimators=100;, score=(train=0.893, test=0.492) total time=   7.1s
# [CV 1/3] END max_depth=20, min_samples_split=10, n_estimators=200;, score=(train=0.889, test=0.583) total time=  14.1s
# [CV 2/3] END max_depth=20, min_samples_split=10, n_estimators=200;, score=(train=0.893, test=0.612) total time=  14.3s
# [CV 3/3] END max_depth=20, min_samples_split=10, n_estimators=200;, score=(train=0.895, test=0.492) total time=  13.9s
# [CV 1/3] END max_depth=20, min_samples_split=10, n_estimators=300;, score=(train=0.897, test=0.583) total time=  21.2s
# [CV 2/3] END max_depth=20, min_samples_split=10, n_estimators=300;, score=(train=0.892, test=0.624) total time=  21.1s
# [CV 3/3] END max_depth=20, min_samples_split=10, n_estimators=300;, score=(train=0.896, test=0.476) total time=  20.7s
# [CV 1/3] END max_depth=20, min_samples_split=15, n_estimators=100;, score=(train=0.845, test=0.607) total time=   7.0s
# [CV 2/3] END max_depth=20, min_samples_split=15, n_estimators=100;, score=(train=0.849, test=0.600) total time=   7.1s
# [CV 3/3] END max_depth=20, min_samples_split=15, n_estimators=100;, score=(train=0.848, test=0.508) total time=   6.8s
# [CV 1/3] END max_depth=20, min_samples_split=15, n_estimators=200;, score=(train=0.841, test=0.571) total time=  14.2s
# [CV 2/3] END max_depth=20, min_samples_split=15, n_estimators=200;, score=(train=0.844, test=0.635) total time=  13.7s
# [CV 3/3] END max_depth=20, min_samples_split=15, n_estimators=200;, score=(train=0.843, test=0.476) total time=  13.5s
# [CV 1/3] END max_depth=20, min_samples_split=15, n_estimators=300;, score=(train=0.844, test=0.583) total time=  20.1s
# [CV 2/3] END max_depth=20, min_samples_split=15, n_estimators=300;, score=(train=0.845, test=0.612) total time=  20.9s
# [CV 3/3] END max_depth=20, min_samples_split=15, n_estimators=300;, score=(train=0.840, test=0.460) total time=  20.6s

# %%
rf.rf_params
# Out:
# {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 100}

# %%
rf.fit_rf(df_train.drop(columns = ['results_points']), df_train['results_points'])

# %%
get_metrics(rf.model, df_test.drop(columns = ['results_points']), df_test['results_points'])
# Out:
# (0.58, 0.9640685089880108, 0.58, 0.58, 0.24)

# %%
plot_cv_results(rf.model_cv, rf.hyper_params[0])
